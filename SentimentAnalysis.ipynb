# %% [markdown]
# <a href="https://colab.research.google.com/github/darshbs/EthicalHackingProject-Internshala/blob/master/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = 'Enter your Consumer Key'
consumer_secret = 'Enter your Consumer secret Key'
access_token = 'Enter your access token'
access_token_secret = 'Enter your access token secret'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
public_tweet = api.search_tweets(q="MiamiGP", lang="en")

for tweet in public_tweet:
  print(tweet.text)
  analysis = TextBlob(tweet.text)
  print(analysis.sentiment)
